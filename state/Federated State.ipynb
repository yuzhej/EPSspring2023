# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data = pd.read_csv("tabletranspose.csv")

# %%
new_header = data.iloc[0] #grab the first row for the header
data = data[1:] #take the data less the header row
data.columns = new_header #set the header row as the df header

# %%
data = data.iloc[1:]

# %%
data=data.rename(columns = {'res_state':'case_month'})

# %%
data.loc[:,'Total'] = data.sum(axis=1)

# %%
data.dtypes
# Out:
# 0
# case_month    object
# AL            object
# AK            object
# AZ            object
# AR            object
# CA            object
# CO            object
# CT            object
# DE            object
# DC            object
# FL            object
# GA            object
# HI            object
# ID            object
# IL            object
# IN            object
# IA            object
# KS            object
# KY            object
# LA            object
# ME            object
# MD            object
# MA            object
# MI            object
# MN            object
# MS            object
# MO            object
# MT            object
# NE            object
# NV            object
# NH            object
# NJ            object
# NM            object
# NY            object
# NC            object
# ND            object
# OH            object
# OK            object
# OR            object
# PA            object
# RI            object
# SC            object
# SD            object
# ...

# %%
data = data.iloc[:, :-1]

# %%
data
# Out:
# 0  case_month      AL     AK      AZ      AR       CA      CO      CT     DE  \
# 2     2020-01     135      0      65      17      368      84      17      0
# 3     2020-02      72      0      57      18      485      95      37      0
# 4     2020-03    2690    238    2691    1156    19396    6814    3822    300
# 5     2020-04    6208    136    7390    2748    46572   12300    9364   4242
# 6     2020-05   11425    145   16188    5354    71217    9298    3658   4380
# 7     2020-06   21949    614   71654   16461   174367    7107   29979   1928
# 8     2020-07   49698   2289   86688   21313   282930   14673    4025   3132
# 9     2020-08   37541   2105   22756   18647   151847    9787    3515   2395
# 10    2020-09   28011   3050   16778   21807   101279   14350    4589   2917
# 11    2020-10   37955   9227   33343   28966   124858   43357   16470   4266
# 12    2020-11   59133  18084  104507   53014   417622  131410   41377  10844
# ...

# %%
from datetime import datetime

# %%
data['case_month'] = pd.to_datetime(data['case_month'],
               format='%Y-%m')

# %%
data.dtypes
# Out:
# 0
# case_month    datetime64[ns]
# AL                    object
# AK                    object
# AZ                    object
# AR                    object
# CA                    object
# CO                    object
# CT                    object
# DE                    object
# DC                    object
# FL                    object
# GA                    object
# HI                    object
# ID                    object
# IL                    object
# IN                    object
# IA                    object
# KS                    object
# KY                    object
# LA                    object
# ME                    object
# MD                    object
# MA                    object
# MI                    object
# MN                    object
# MS                    object
# MO                    object
# MT                    object
# NE                    object
# NV                    object
# NH                    object
# NJ                    object
# ...

# %%
data.loc[:,'Total'] = data.sum(axis=1)
# Out:
# /var/folders/0l/8bcxdbyd5yv7s_yyh3qrqh300000gn/T/ipykernel_16603/1660957538.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.loc[:,'Total'] = data.sum(axis=1)

# %%
data
# Out:
# 0  case_month      AL     AK      AZ      AR       CA      CO      CT     DE  \
# 2  2020-01-01     135      0      65      17      368      84      17      0
# 3  2020-02-01      72      0      57      18      485      95      37      0
# 4  2020-03-01    2690    238    2691    1156    19396    6814    3822    300
# 5  2020-04-01    6208    136    7390    2748    46572   12300    9364   4242
# 6  2020-05-01   11425    145   16188    5354    71217    9298    3658   4380
# 7  2020-06-01   21949    614   71654   16461   174367    7107   29979   1928
# 8  2020-07-01   49698   2289   86688   21313   282930   14673    4025   3132
# 9  2020-08-01   37541   2105   22756   18647   151847    9787    3515   2395
# 10 2020-09-01   28011   3050   16778   21807   101279   14350    4589   2917
# 11 2020-10-01   37955   9227   33343   28966   124858   43357   16470   4266
# 12 2020-11-01   59133  18084  104507   53014   417622  131410   41377  10844
# ...

# %%
data['AL'] = pd.to_numeric(data['AL'])

# %%
data = data.iloc[:, :-1]

# %%
data.loc[:,'Total'] = data.sum(axis=1)
# Out:
# /var/folders/0l/8bcxdbyd5yv7s_yyh3qrqh300000gn/T/ipykernel_16603/1660957538.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.loc[:,'Total'] = data.sum(axis=1)

# %%
data
# Out:
# 0  case_month      AL     AK      AZ      AR       CA      CO      CT     DE  \
# 2  2020-01-01     135      0      65      17      368      84      17      0
# 3  2020-02-01      72      0      57      18      485      95      37      0
# 4  2020-03-01    2690    238    2691    1156    19396    6814    3822    300
# 5  2020-04-01    6208    136    7390    2748    46572   12300    9364   4242
# 6  2020-05-01   11425    145   16188    5354    71217    9298    3658   4380
# 7  2020-06-01   21949    614   71654   16461   174367    7107   29979   1928
# 8  2020-07-01   49698   2289   86688   21313   282930   14673    4025   3132
# 9  2020-08-01   37541   2105   22756   18647   151847    9787    3515   2395
# 10 2020-09-01   28011   3050   16778   21807   101279   14350    4589   2917
# 11 2020-10-01   37955   9227   33343   28966   124858   43357   16470   4266
# 12 2020-11-01   59133  18084  104507   53014   417622  131410   41377  10844
# ...

# %%
data = data.iloc[:, :-1]

# %%
data['AK'] = pd.to_numeric(data['AK'])

# %%
data.columns[3:]
# Out:
# Index(['AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA', 'HI', 'ID', 'IL',
#        'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO',
#        'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR',
#        'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI',
#        'WY', 'GU', 'PR', 'VI'],
#       dtype='object', name=0)

# %%
names = ['AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA', 'HI', 'ID', 'IL',
       'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN', 'MS', 'MO',
       'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH', 'OK', 'OR',
       'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA', 'WV', 'WI',
       'WY', 'GU', 'PR', 'VI']

# %%
for name in names:
    data[name] = pd.to_numeric(data[name])

# %%
data.dtypes
# Out:
# 0
# case_month    datetime64[ns]
# AL                     int64
# AK                     int64
# AZ                     int64
# AR                     int64
# CA                     int64
# CO                     int64
# CT                     int64
# DE                     int64
# DC                     int64
# FL                     int64
# GA                     int64
# HI                     int64
# ID                     int64
# IL                     int64
# IN                     int64
# IA                     int64
# KS                     int64
# KY                     int64
# LA                     int64
# ME                     int64
# MD                     int64
# MA                     int64
# MI                     int64
# MN                     int64
# MS                     int64
# MO                     int64
# MT                     int64
# NE                     int64
# NV                     int64
# NH                     int64
# NJ                     int64
# ...

# %%
data.loc[:,'Total'] = data.sum(axis=1)
# Out:
# /var/folders/0l/8bcxdbyd5yv7s_yyh3qrqh300000gn/T/ipykernel_16603/1660957538.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.loc[:,'Total'] = data.sum(axis=1)

# %%
data
# Out:
# 0  case_month      AL     AK      AZ      AR       CA      CO      CT     DE  \
# 2  2020-01-01     135      0      65      17      368      84      17      0
# 3  2020-02-01      72      0      57      18      485      95      37      0
# 4  2020-03-01    2690    238    2691    1156    19396    6814    3822    300
# 5  2020-04-01    6208    136    7390    2748    46572   12300    9364   4242
# 6  2020-05-01   11425    145   16188    5354    71217    9298    3658   4380
# 7  2020-06-01   21949    614   71654   16461   174367    7107   29979   1928
# 8  2020-07-01   49698   2289   86688   21313   282930   14673    4025   3132
# 9  2020-08-01   37541   2105   22756   18647   151847    9787    3515   2395
# 10 2020-09-01   28011   3050   16778   21807   101279   14350    4589   2917
# 11 2020-10-01   37955   9227   33343   28966   124858   43357   16470   4266
# 12 2020-11-01   59133  18084  104507   53014   417622  131410   41377  10844
# ...

# %%
plt.figure(figsize=(17, 8))
plt.plot(data.Total)
plt.title('Total of Covid Cases')
plt.ylabel('Number of individuals')
plt.xlabel('Case Month')
plt.grid(False)
plt.show()

# %%
data.set_index('case_month',drop=True,inplace=True)

# %%
#General View
plt.figure(figsize=(17, 8))
plt.plot(data.Total)
plt.title('Total of Covid Cases')
plt.ylabel('Number of individuals')
plt.xlabel('Case Month')
plt.grid(False)
plt.show()

# %%
from sklearn.metrics import r2_score, median_absolute_error, mean_absolute_error
from sklearn.metrics import median_absolute_error, mean_squared_error, mean_squared_log_error

# %%
from scipy.optimize import minimize
import statsmodels.tsa.api as smt
import statsmodels.api as sm

# %%
from tqdm import tqdm_notebook

from itertools import product

# %%
def mean_absolute_percentage_error(y_true, y_pred):
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
def plot_moving_average(series, window, plot_intervals=False, scale=1.96):

    rolling_mean = series.rolling(window=window).mean()
    
    plt.figure(figsize=(17,8))
    plt.title('Moving average\n window size = {}'.format(window))
    plt.plot(rolling_mean, 'g', label='Rolling mean trend')
    
    #Plot confidence intervals for smoothed values
    if plot_intervals:
        mae = mean_absolute_error(series[window:], rolling_mean[window:])
        deviation = np.std(series[window:] - rolling_mean[window:])
        lower_bound = rolling_mean - (mae + scale * deviation)
        upper_bound = rolling_mean + (mae + scale * deviation)
        plt.plot(upper_bound, 'r--', label='Upper bound / Lower bound')
        plt.plot(lower_bound, 'r--')
            
    plt.plot(series[window:], label='Actual values')
    plt.legend(loc='best')
    plt.grid(True)

# %%
plot_moving_average(data.Total, 2)

# %%
plot_moving_average(data.Total, 3, plot_intervals=True)

# %%
def exponential_smoothing(series, alpha):

    result = [series[0]] # first value is same as series
    for n in range(1, len(series)):
        result.append(alpha * series[n] + (1 - alpha) * result[n-1])
    return result

# %%
def plot_exponential_smoothing(series, alphas):
 
    plt.figure(figsize=(17, 8))
    for alpha in alphas:
        plt.plot(exponential_smoothing(series, alpha), label="Alpha {}".format(alpha))
    plt.plot(series.values, "c", label = "Actual")
    plt.legend(loc="best")
    plt.axis('tight')
    plt.title("Exponential Smoothing")
    plt.grid(True);

# %%
plot_exponential_smoothing(data.Total, [0.05, 0.5])

# %%
def double_exponential_smoothing(series, alpha, beta):

    result = [series[0]]
    for n in range(1, len(series)+1):
        if n == 1:
            level, trend = series[0], series[1] - series[0]
        if n >= len(series): # forecasting
            value = result[-1]
        else:
            value = series[n]
        last_level, level = level, alpha * value + (1 - alpha) * (level + trend)
        trend = beta * (level - last_level) + (1 - beta) * trend
        result.append(level + trend)
    return result

def plot_double_exponential_smoothing(series, alphas, betas):
     
    plt.figure(figsize=(17, 8))
    for alpha in alphas:
        for beta in betas:
            plt.plot(double_exponential_smoothing(series, alpha, beta), label="Alpha {}, beta {}".format(alpha, beta))
    plt.plot(series.values, label = "Actual")
    plt.legend(loc="best")
    plt.axis('tight')
    plt.title("Double Exponential Smoothing")
    plt.grid(True)

# %%
plot_double_exponential_smoothing(data.Total, alphas=[0.9, 0.02], betas=[0.9, 0.02])

# %%
def tsplot(y, lags=None, figsize=(12, 7), syle='bmh'):
    
    if not isinstance(y, pd.Series):
        y = pd.Series(y)
        
    with plt.style.context(style='bmh'):
        fig = plt.figure(figsize=figsize)
        layout = (2,2)
        ts_ax = plt.subplot2grid(layout, (0,0), colspan=2)
        acf_ax = plt.subplot2grid(layout, (1,0))
        pacf_ax = plt.subplot2grid(layout, (1,1))
        
        y.plot(ax=ts_ax)
        p_value = sm.tsa.stattools.adfuller(y)[1]
        ts_ax.set_title('Time Series Analysis Plots\n Dickey-Fuller: p={0:.5f}'.format(p_value))
        smt.graphics.plot_acf(y, lags=lags, ax=acf_ax)
        smt.graphics.plot_pacf(y, lags=lags, ax=pacf_ax)
        plt.tight_layout()

# %%
tsplot(data.Total, lags=2)
# Out:
# /Users/jaysonjin/Downloads/federated/venv/lib/python3.10/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
plot_exponential_smoothing(data.AL, [0.05, 0.5])

# %%
exponential_smoothing(data.Total, 0.5)
# Out:
# [4181,
#  4258.5,
#  189205.75,
#  500248.375,
#  611831.6875,
#  853977.84375,
#  1323797.421875,
#  1374697.7109375,
#  1315375.35546875,
#  1706732.177734375,
#  3090172.5888671875,
#  4578318.294433594,
#  5080771.647216797,
#  3628144.8236083984,
#  2733613.411804199,
#  2230668.7059020996,
#  1582432.3529510498,
#  1029199.6764755249,
#  1386407.3382377625,
#  2860974.669118881,
#  3257438.3345594406,
#  2757346.6672797203,
#  2642244.33363986,
#  4907088.66681993,
#  10756904.333409965,
#  6863250.1667049825,
#  3970864.0833524913,
#  2675191.5416762456,
#  2928958.770838123,
#  2903880.3854190614,
#  3129515.1927095307,
#  2933577.0963547654,
#  2262888.048177383,
#  1719375.0240886915,
#  1674673.0120443457,
#  1745037.506022173,
#  1565370.2530110865,
#  1242422.6265055432,
#  890845.3132527716]

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing

# %%
train = data[:'2022-07-01']
test = data['2022-08-01':]
len(test)
# Out:
# 8

# %%
ses_model = SimpleExpSmoothing(train.Total).fit(smoothing_level=0.5)

y_pred = ses_model.forecast(8)

mean_absolute_error(test.Total, y_pred)
# Out:
# /Users/jaysonjin/Downloads/federated/venv/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# 1655075.3177137915

# %%
mean_absolute_percentage_error(test.Total, y_pred)
# Out:
# 160.99094526777898

# %%
test.Total
# Out:
# case_month
# 2022-08-01    2737639
# 2022-09-01    1592199
# 2022-10-01    1175862
# 2022-11-01    1629971
# 2022-12-01    1815402
# 2023-01-01    1385703
# 2023-02-01     919475
# 2023-03-01     539268
# Name: Total, dtype: int64

# %%
y_pred
# Out:
# 2022-08-01    3.129515e+06
# 2022-09-01    3.129515e+06
# 2022-10-01    3.129515e+06
# 2022-11-01    3.129515e+06
# 2022-12-01    3.129515e+06
# 2023-01-01    3.129515e+06
# 2023-02-01    3.129515e+06
# 2023-03-01    3.129515e+06
# Freq: MS, dtype: float64

# %%
train.Total.plot(title="Single Exponential Smoothing")
test.Total.plot()
y_pred.plot()
plt.show()

# %%
levels=[0.05, 0.1,0.15, 0.2,0.25, 0.3,0.35, 0.4,0.45, 0.5]

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
d = []

# %%
for level in levels:
    try:
        ses_model = SimpleExpSmoothing(train.AL).fit(smoothing_level=level)
        y_pred = ses_model.forecast(8)
        mabse = mean_absolute_error(test.AL, y_pred)
        mabspe = mean_absolute_percentage_error(test.AL, y_pred)
        d.append(
            {
                'Level': level,
                'MABSE': mabse,
                'MABSPE': mabspe
            }
        )
    except:
        continue

# %%
x=pd.DataFrame(d)

# %%
x
# Out:
#    Level         MABSE      MABSPE
# 0   0.05  26341.695320  184.739413
# 1   0.10  30030.580428  210.399656
# 2   0.15  31050.432472  217.493846
# 3   0.20  30417.491653  213.091048
# 4   0.25  29274.331028  205.139112
# 5   0.30  28234.319862  197.904693
# 6   0.35  27585.057453  193.388361
# 7   0.40  27432.439326  192.326734
# 8   0.45  27775.619323  194.713928
# 9   0.50  28552.375664  200.117120

# %%
x[x['MABSPE']==x['MABSPE'].min()]
# Out:
#    Level        MABSE      MABSPE
# 0   0.05  26341.69532  184.739413

# %%
states = data.columns[0:54]

# %%
s=pd.DataFrame()

# %%
d = []

# %%
for state in states:
    for level in levels:
        try:
            ses_model = SimpleExpSmoothing(train[state]).fit(smoothing_level=level)
            y_pred = ses_model.forecast(8)
            mabse = mean_absolute_error(test[state], y_pred)
            mabspe = np.mean(np.abs((test[state] - y_pred) / test[state]))*100
            d.append(
                {
                    'State': state,
                    'Level': level,
                    'Mean Absolute Error': mabse,
                    'Mean Absolute Percentage Error': mabspe
                }
            )
        except:
            continue

# %%
z=pd.DataFrame(d)

# %%
z
# Out:
#     State  Level  Mean Absolute Error  Mean Absolute Percentage Error
# 0      AL   0.05         26341.695320                      184.739413
# 1      AL   0.10         30030.580428                      210.399656
# 2      AL   0.15         31050.432472                      217.493846
# 3      AL   0.20         30417.491653                      213.091048
# 4      AL   0.25         29274.331028                      205.139112
# ..    ...    ...                  ...                             ...
# 535    VI   0.30           981.435470                      490.684378
# 536    VI   0.35           958.277707                      480.538200
# 537    VI   0.40           926.316261                      466.534840
# 538    VI   0.45           889.303892                      450.318504
# 539    VI   0.50           849.095414                      432.701848
#
# [540 rows x 4 columns]

# %%
states
# Out:
# Index(['AL', 'AK', 'AZ', 'AR', 'CA', 'CO', 'CT', 'DE', 'DC', 'FL', 'GA', 'HI',
#        'ID', 'IL', 'IN', 'IA', 'KS', 'KY', 'LA', 'ME', 'MD', 'MA', 'MI', 'MN',
#        'MS', 'MO', 'MT', 'NE', 'NV', 'NH', 'NJ', 'NM', 'NY', 'NC', 'ND', 'OH',
#        'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX', 'UT', 'VT', 'VA', 'WA',
#        'WV', 'WI', 'WY', 'GU', 'PR', 'VI'],
#       dtype='object', name=0)

# %%
z.to_csv('z.csv')

# %%
ses_model = SimpleExpSmoothing(train.Total).fit(smoothing_level=0.32)

y_pred = ses_model.forecast(8)

mean_absolute_error(test.Total, y_pred)
# Out:
# 1846940.5833717878

# %%
mean_absolute_percentage_error(test.Total, y_pred)
# Out:
# 176.99185721884407

# %%
train.Total.plot(title="Single Exponential Smoothing")
test.Total.plot()
y_pred.plot()
plt.show()

# %%
y_pred
# Out:
# 2022-08-01    1215.845414
# 2022-09-01    1215.845414
# 2022-10-01    1215.845414
# 2022-11-01    1215.845414
# 2022-12-01    1215.845414
# 2023-01-01    1215.845414
# 2023-02-01    1215.845414
# 2023-03-01    1215.845414
# Freq: MS, dtype: float64

# %%
test.Total
# Out:
# case_month
# 2022-08-01    2737639
# 2022-09-01    1592199
# 2022-10-01    1175862
# 2022-11-01    1629971
# 2022-12-01    1815402
# 2023-01-01    1385703
# 2023-02-01     919475
# 2023-03-01     539268
# Name: Total, dtype: int64

# %%
np.mean(np.abs((test.Total - y_pred) / test.Total))*100
# Out:
# 99.89860261911284

# %%
mean_absolute_percentage_error(test.Total, y_pred)
# Out:
# 99.89860261911284

# %%
ses_model = SimpleExpSmoothing(train['CA']).fit(smoothing_level=0.5)
y_pred = ses_model.forecast(8)
mabse = mean_absolute_error(test['CA'], y_pred)
mabspe = np.mean(np.abs((test['CA'] - y_pred) / test['CA']))*100

# %%
test['CA']
# Out:
# case_month
# 2022-08-01    344911
# 2022-09-01    145993
# 2022-10-01    101431
# 2022-11-01    207097
# 2022-12-01    278608
# 2023-01-01    124282
# 2023-02-01     98839
# 2023-03-01     53851
# Name: CA, dtype: int64

# %%
y_pred
# Out:
# 2022-08-01    525039.98677
# 2022-09-01    525039.98677
# 2022-10-01    525039.98677
# 2022-11-01    525039.98677
# 2022-12-01    525039.98677
# 2023-01-01    525039.98677
# 2023-02-01    525039.98677
# 2023-03-01    525039.98677
# Freq: MS, dtype: float64

# %%
np.abs((test['CA'] - y_pred) / test['CA'])
# Out:
# case_month
# 2022-08-01    0.522248
# 2022-09-01    2.596337
# 2022-10-01    4.176327
# 2022-11-01    1.535237
# 2022-12-01    0.884512
# 2023-01-01    3.224586
# 2023-02-01    4.312073
# 2023-03-01    8.749865
# dtype: float64

# %%
np.mean(np.abs((test['CA'] - y_pred) / test['CA']))
# Out:
# 3.2501479662428503

# %%
train.CA.plot(title="Single Exponential Smoothing")
test.CA.plot()
y_pred.plot()
plt.show()
